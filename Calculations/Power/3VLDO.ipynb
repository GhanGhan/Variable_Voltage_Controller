# %% [markdown]
# # MCP1700T-3002E/
# - Input Operating Voltage Range: 2.3V to 6.0V
# - 1.6uA Typical Quiscent Current, max is 4uA (value increases with Vin)
# - 250mA Output Current
# - Typical Output Voltage tolerance is 0.4%, max is 3%
# - stable with 1.0uF Ceramic output capacitor
# - Short circuit protection
# - Overtemperature protection
# - ![image.png](attachment:02ffbc98-0458-4268-b793-5b97213ef7fb.png)
# - ![image.png](attachment:cfb938ce-e5ee-479e-b4b3-6c96d01901e8.png)

# %% [markdown]
# # Product Identification System
# -![image.png](attachment:a1a1a6f5-2aca-4c8c-8912-60f45d733208.png)
